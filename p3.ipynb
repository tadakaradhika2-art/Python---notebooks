# %%
students=[{"name":"Aarav sharma","marks":78},{"name":"priya patel","marks":65},{"name":"rohan gupta","marks":88},{"name":"ananya iyer","marks":72}]
total=0
for i in students:
    total=total+i["marks"]
print("total marks:",total)
# Out:
# total marks: 303

# %%
students=[{"name":"Aarav sharma","marks":78},{"name":"priya patel","marks":65},{"name":"rohan gupta","marks":88},{"name":"ananya iyer","marks":72}]
for i in students:
    print(i["name"])
# Out:
# Aarav sharma
# priya patel
# rohan gupta
# ananya iyer
