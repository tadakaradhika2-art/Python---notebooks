# %%
num=[1,2,3,4,5]
print(sum(num))
# Out:
# 15

# %%
nums=[1,2,4,6,9]
a=min(nums)
b=max(nums)
print("largest:",a)
print("smallest:",b)
# Out:
# largest: 1
# smallest: 9

# %%
number=[2,4,5,1,9,3]
even=0
odd=0
for i in number:
    if i%2 ==0:
      even=even+1
    else:
      odd=odd+1
print("even:",even)
print("odd:",odd)
# Out:
# even: 2
# odd: 4

# %%
marks=[5,8,3,9,1,7]
print(marks[::-1])
# Out:
# [7, 1, 9, 3, 8, 5]
